# %% [markdown]
# ## PyTorch - AutoGrad (automatic differentiation)

# %%
import torch

# %%
# the python debugger
import pdb

# %%
from torch.autograd import Variable

x = Variable(torch.randn(1, 10))
prev_h = Variable(torch.randn(1, 20))
W_h = Variable(torch.randn(20, 20))
W_x = Variable(torch.randn(20, 10))

pdb.set_trace()

i2h = torch.mm(W_x, x.t())
h2h = torch.mm(W_h, prev_h.t())

next_h = i2h + h2h
next_h = next_h.tanh()
# Out:
# --Return--
# > <ipython-input-3-8e2d6f24d830>(8)<module>()->None
# -> pdb.set_trace()
# (Pdb) a
# (Pdb) v
# *** NameError: name 'v' is not defined
# (Pdb) x
# tensor([[ 0.2406, -2.1995, -0.3088, -0.9960,  1.1188,  0.9809,  0.1124,  0.1503,
#          -0.9284,  1.1889]])
# (Pdb) prev_h
# tensor([[ 0.2227,  0.0499, -0.9019,  0.0652,  0.0026,  1.4007,  0.3241, -0.7835,
#          -1.5462, -0.4036, -0.7867,  0.3975,  0.4649,  1.3110, -0.3008,  0.6338,
#          -0.5250, -1.9106, -0.2453, -0.6971]])
# (Pdb) W_h
# tensor([[-0.4750,  0.3251, -1.4694,  0.1566, -1.2948, -1.3354,  1.4007, -0.5003,
#           0.0045, -2.1496, -0.1962,  0.4213,  0.8803,  0.0571, -1.9084,  0.9993,
#           1.0485, -1.2454, -0.2734,  0.2367],
#         [-0.2207, -0.7762, -0.5875,  0.2857, -1.6234, -0.5717, -0.5769,  0.6784,
#          -0.9650, -0.5629,  1.8365,  0.9704, -2.3469,  1.1656, -0.0102, -0.2687,
#           1.1875, -1.2333, -0.6341,  0.6625],
#         [ 3.4684, -0.2243, -0.3495,  2.0113, -0.7801,  0.7691,  0.1414,  1.2809,
#          -0.9840, -0.1353,  1.1360,  2.1548,  0.5525, -0.0567,  1.1397,  0.4703,
#           0.9690,  2.7818, -0.3334, -0.4992],
#         [-1.4462, -1.2708,  1.3613, -1.6116, -0.7150, -1.3904, -0.4923,  0.2734,
#          -0.8170, -1.2407, -2.0801,  0.2078, -0.3297, -1.4164, -1.7237, -1.3885,
#          -0.8804, -1.0943,  0.4141, -1.4473],
#         [-0.1889, -0.6011,  0.9641, -0.9592,  0.7798,  0.2526, -0.9919,  0.5193,
#           1.1054,  0.1320,  1.7485,  2.4018,  0.7583,  0.5301,  0.8849,  0.3249,
#           0.1763, -1.4380,  0.2076,  0.4020],
#         [-0.2566,  0.4898, -0.5910, -0.7588, -0.1638, -0.0259, -2.4723, -0.5809,
#           0.2725, -1.4798, -1.3090, -0.8274,  0.8401,  0.7820,  0.5436, -1.4830,
#           0.7892, -0.8171, -0.9073, -0.0585],
#         [ 0.6234,  0.7736, -1.1607, -1.8713,  0.0060, -0.0526, -0.8509,  1.3700,
#           0.1657,  1.4014, -0.4320,  0.6599,  0.1932, -0.2709,  0.6718,  0.7776,
#           1.4209, -0.5848, -0.3478, -2.0286],
#         [ 0.3313,  0.0414,  1.3428, -1.4076,  0.4015, -0.8545,  0.3729, -0.5264,
#          -1.9882,  2.5266, -0.9064, -0.5496, -1.0954,  0.4198,  1.4338,  0.5079,
#          -0.8679, -0.5179,  0.4360,  0.8484],
#         [-3.0686, -0.2169,  0.4755, -1.1280,  1.2382,  0.8056,  0.4621, -0.5220,
#          -0.7201, -0.5132, -0.2666, -0.8668,  0.0817, -0.8681,  0.2622, -1.6580,
#          -0.1672, -0.4703, -1.2989,  0.1486],
#         [-0.1389,  0.3290,  0.6622,  1.5889, -0.4379, -1.6288,  0.7543,  0.0497,
#          -0.8600,  0.2731, -0.4902,  0.5572, -0.2352, -0.3682, -0.0872,  0.4308,
#           0.0003, -0.5463,  1.0399, -0.1365],
#         [-0.0900,  1.7187,  0.6805,  2.4953,  1.1211,  0.6596, -0.0850, -0.5883,
#          -2.7250,  0.4172,  1.5777,  0.4888,  1.0590,  0.2924,  1.4996, -1.0001,
#           0.4629, -1.6647,  0.3444,  0.0501],
#         [ 0.4375, -1.0718,  0.7113,  0.1226, -0.1070, -0.2964,  0.8955,  0.0680,
#          -0.5101, -0.5955,  0.9991, -0.9536, -1.1235, -1.3898,  0.5252,  0.5470,
#          -0.1240,  1.6227,  1.1754, -0.3283],
#         [-0.8396, -0.0384, -1.0191, -1.1789, -2.0092,  2.2795,  0.2374,  0.8009,
#           0.1418, -0.9055,  0.5981, -1.3459,  0.1655, -0.7542,  0.8153, -0.5514,
#           0.8364, -0.6962,  1.6884,  0.2397],
#         [ 0.2170,  0.9109,  1.0142,  0.4149,  0.4299, -1.2337,  0.1716, -1.8079,
#           2.1137, -1.1140, -0.2448,  1.0865, -0.0152, -0.8004,  2.0176,  0.1042,
#           0.8126,  0.7627,  0.6406, -1.4023],
#         [-0.4320, -1.6613,  1.0814,  0.4063, -1.2311,  0.3724, -0.0807,  0.7646,
#          -0.4981, -0.7179,  1.4563, -0.0904,  1.1505,  1.0672, -1.3941,  0.5543,
#           0.9856, -1.2092, -1.4474,  0.3372],
#         [-0.1265, -2.1920, -0.8117,  0.0354,  0.3685,  0.8415, -0.1614, -0.7952,
#          -0.3410,  0.3908,  0.0555,  0.3021,  0.8329, -0.0380,  0.3141, -0.5035,
#           0.2158, -1.7239,  1.6031, -0.1584],
#         [ 1.0403, -0.2006,  0.1049,  1.3257, -0.9506, -0.4759, -0.3571,  0.2413,
#           0.3385, -1.3291, -1.4806, -0.7383, -1.2187,  1.1993,  0.4468,  2.3999,
#           0.0945, -0.7316,  1.4797, -1.7865],
#         [-0.3507, -0.5797,  0.7089,  0.2185, -0.6975,  1.5109, -2.2217,  3.1305,
#          -0.5551, -0.5940,  0.6092, -1.5694,  0.3915,  1.4007,  0.1075,  0.3789,
#           0.6588,  0.8139,  0.3087,  0.7885],
#         [ 1.0090,  1.2511,  0.4298,  0.1490, -0.8376, -1.1195, -0.7128,  2.0449,
#          -1.9178,  0.5079,  0.7126, -1.1489,  0.3181,  1.7464,  1.8565,  1.1031,
#          -0.3181, -0.8746, -0.5820,  2.1892],
#         [ 0.5173, -0.9521,  0.6876,  1.7545, -0.5646,  1.4579,  0.1168, -0.0716,
#          -1.7253,  0.1897,  0.2242, -1.0973,  0.5945,  2.5655,  0.6159, -0.4623,
#          -0.6615, -1.2117,  0.6671,  0.3552]])
# (Pdb) next_h
# *** NameError: name 'next_h' is not defined
# (Pdb) i2h
# *** NameError: name 'i2h' is not defined

# %%
x

# %%
type(x)

# %%
x.size

# %%
x.type
