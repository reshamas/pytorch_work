# %% [markdown]
# ## Example of MNIST - read into Numpy array

# %%
# !pwd
# Out:
# /Users/reshamashaikh/ds/my_repos/pytorch_work

# %%
path = '/Users/reshamashaikh/Downloads/'

# %% [raw]
# path_data = '/Users/reshamashaikh/ds/my_repos/pytorch_work/data/'

# %%
""" A function that can read MNIST's idx file format into numpy arrays.

    The MNIST data files can be downloaded from here:
    
    http://yann.lecun.com/exdb/mnist/

    This relies on the fact that the MNIST dataset consistently uses
    unsigned char types with their data segments.
"""

import struct

import numpy as np

def read_idx(filename):
    with open(filename, 'rb') as f:
        zero, data_type, dims = struct.unpack('>HBB', f.read(4))
        shape = tuple(struct.unpack('>I', f.read(4))[0] for d in range(dims))
        return np.fromstring(f.read(), dtype=np.uint8).reshape(shape)

# %%
"""Four files are available on this site:

train-images-idx3-ubyte.gz:  training set images (9912422 bytes) 
train-labels-idx1-ubyte.gz:  training set labels (28881 bytes) 
t10k-images-idx3-ubyte.gz:   test set images (1648877 bytes) 
t10k-labels-idx1-ubyte.gz:   test set labels (4542 bytes)
"""    
# download data to default Downloads directory
# !wget $path_data http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
#!wget http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
#!wget http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
#!wget http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Out:
# --2018-08-31 07:50:24--  http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Resolving yann.lecun.com... 216.165.22.6
# Connecting to yann.lecun.com|216.165.22.6|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9912422 (9.5M) [application/x-gzip]
# Saving to: 'train-images-idx3-ubyte.gz'
#
# train-images-idx3-u 100%[=====================>]   9.45M  6.07MB/s   in 1.6s
#
# 2018-08-31 07:50:25 (6.07 MB/s) - 'train-images-idx3-ubyte.gz' saved [9912422/9912422]

# %%
# !ls -alt $path
# Out:
# total 15434208
# drwx------+ 570 reshamashaikh  staff       18240 Aug 31 07:41 .
# -rw-r--r--    1 reshamashaikh  staff       60008 Aug 31 07:30 train-labels-idx1-ubyte
# drwxr-xr-x+  52 reshamashaikh  staff        1664 Aug 31 07:26 ..
# -rw-r--r--@   1 reshamashaikh  staff       22532 Aug 31 07:25 .DS_Store
# -rw-r--r--@   1 reshamashaikh  staff    47040016 Aug 31 07:25 train-images-idx3-ubyte
# -rw-r--r--@   1 reshamashaikh  staff     9912422 Aug 31 07:24 train-images-idx3-ubyte.gz
# -rw-r--r--@   1 reshamashaikh  staff       84424 Aug 28 16:58 datanauts-logo-purple.png
# -rw-r--r--@   1 reshamashaikh  staff      563639 Aug 27 18:43 optdigits.tra
# -rw-r--r--@   1 reshamashaikh  staff       86399 Aug 26 19:23 Fax Message 5 pages 1-1.pdf
# -rw-r--r--@   1 reshamashaikh  staff     2494225 Aug 26 17:41 1512.02325.pdf
# -rw-r--r--@   1 reshamashaikh  staff   101569348 Aug 26 17:32 Mendeley-Desktop-1.19.2-OSX-Universal.dmg
# ...

# %%
#!gunzip train-images-idx3-ubyte.gz
#!gunzip {path}train-labels-idx1-ubyte.gz
# !gunzip {path}t10k-images-idx3-ubyte.gz
#!gunzip $path/t10k-labels-idx1-ubyte.gz
# Out:
# gunzip: can't stat: /Users/reshamashaikh/Downloads/t10k-images-idx3-ubyte.gz (/Users/reshamashaikh/Downloads/t10k-images-idx3-ubyte.gz.gz): No such file or directory

# %%
X_train = read_idx(path+'train-images-idx3-ubyte')
y_train = read_idx(path+'train-labels-idx1-ubyte')

X_test = read_idx(path+'t10k-images-idx3-ubyte')
y_test = read_idx(path+'t10k-labels-idx1-ubyte')
# Out:
# /Users/reshamashaikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-49-4c7435531724> in <module>()
#       2 y_train = read_idx(path+'train-labels-idx1-ubyte')
#       3
# ----> 4 X_test = read_idx(path+'t10k-images-idx3-ubyte')
#       5 y_test = read_idx(path+'t10k-labels-idx1-ubyte')
#
# <ipython-input-36-cc3bbabab4fc> in read_idx(filename)
#      14
#      15 def read_idx(filename):
# ---> 16     with open(filename, 'rb') as f:
#      17         zero, data_type, dims = struct.unpack('>HBB', f.read(4))
#      18         shape = tuple(struct.unpack('>I', f.read(4))[0] for d in range(dims))
#
# ...

# %%
print(X_train.shape)
# Out:
# (60000, 28, 28)
